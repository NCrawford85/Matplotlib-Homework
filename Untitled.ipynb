# %%
#create a summaray data frame for mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
#kept getting syntax error trying this way.  Need to figure out why, but meantime I just hashed it out
#def summary(x):
    #summary_columns = {'Mean Tumor Volume': x['Tumor Volume (mm3)'].mean(),
                    #  'Median Tumor Volume': x['Tumor Volume (mm3)'].median(),
                    #  'Tumor Volume Variance': x['Tumor Volume (mm3)'].var(),
                    #  'Standard Deviation': x['Tumor Volume (mm3)'].std(),
                    #  'SEM': x['Tumor Volume (mm3)'].sem}
   #return pd.Series(summary_columns, index = ['Mean Tumor Volume','Median Tumor Volume','Tumor Volume Variance','Standard Deviation','SEM']
#summary_table = combined_results.groupby(['Drug Regimen']).apply(summary)
combined_results

# %%
#group results by drug regimen
#did this the clunky way because I couldn't make my function work above.  
#So weird because it worked just fine for the pandas project.

#drug_results = combined_results.groupby(['Drug Regimen'])

drug_summary = pd.DataFrame()
#calculate mean tumor volume
drug_summary['Mean'] = pd.DataFrame(combinded_results.groupby(['Drug Regimen'])['Tumor Volume (mm3)'].mean()

#calculate median tumor volume
#drug_summary['Median'] = pd.DataFrame(drug_results['Tumor Volume (mm3)'].median())

#caclulate variance
#drug_summary['Variance'] = pd.DataFrame(drug_results['Tumor Volume (mm3)'].var())

#calculate standard deviation
#drug_summary["Standard Deivation"] = pd.DataFrame(drug_results['Tumor Volume (mm3)'].std())


#calculate sem
#drug_summary['SEM'] = pd.DataFrame(drug_results['Tumor Volume (mm3)'].sem())
#get a list of drugs for the index
#drug_count = combined_results['Drug Regimen'].unique()


#drug_summary.rename(columns={})
#display the data frame
drug_summary.head()

# %%
#merge the dataframes
#drug_summary = pd.merge(drug_results_mean,drug_results_median, on = 'Drug Regimen')
#drug_summary = pd.merge(drug_summary, drug_results_var, on = 'Drug Regimen')
#drug_summary = pd.merge(drug_summary, drug_results_std, on = 'Drug Regimen')
#drug_summary = pd.merge(drug_summary, drug_results_sem, on = 'Drug Regimen')
#rename the column names
#drug.summary = drug_summary.rename(columns={ drug_summary.columns[0]: "Mean Tumor Volume (mm3)", 
#                             drug_summary.columns[1]:'Median Tumor Volume',
#                             drug_summary.columns[2]:'VAR',
#                             drug_summary.columns[3]: 'Standard Deviation', 
#                                            drug_summary.columns[4]: 'SEM'})


#I had huge trouble renaming column names
#tried this method, and it didn't work
#drug_summary = drug_summary.rename(columns={'Tumor Volume (mm3)_x': 'Mean Tumor Volume (mm3)',
#                                          'Tumor Volume (mm3)_y' : 'Median Tumor Volume (mm3)',
#                                        'Tumor Volume (mm3)_x' : 'Tumor Volume Variance',
#                                           'Tumor Volume (mm3)_y' : 'Standard Deviation',
#                                         'Tumor Volume (mm3)' : 'SEM'
#                                       })
#Tried this method and it didn't work
#drug_summary.columns['Mean Tumor Volume (mm3)','Median Tumor Volume (mm3)','Tumor Volume Variance','Standard Deviation','SEM']

#I also attempted to rename the column names of the new dataframes before merging which had no effect
#rename the column title
#drug_results_mean.rename(columns={'Tumor Volume (mm3)':'Mean Tumor Volume'})
#rename the column title
#drug_results_median.rename(columns={'Tumor Volume (mm3)':'Median Tumor Volume'})
#rename the column title
#drug_results_var.rename(columns={'Tumor Volume (mm3)':'Variance'})
#rename the column title
#drug_results_std.rename(columns={'Tumor Volume (mm3)':'Standard Deviation'})
#rename the column title
#drug_results_sem.rename(columns={'Tumor Volume (mm3)':'SEM'})

#I even tried making a new dataframe but couldn't get the index to work
#wit's end here
#drug_lib = ({"Mean Tumor Volume": drug_results_mean, 
#            "Median Tumor Volume": drug_results_median, 
#            "Tumor Volume Variance":drug_results_var,
#           "Standard Deviation": drug_results_std,
#           "SEM": drug_results_sem})
#drug_summary = pd.DataFrame(drug_lib, index=['Mean Tumor Volume', 'Median Tumor Volume','Tumor Volume Variance', 'Standard Deviation','SEM'])

# %%
indexed_results = filtered_results.set_index('Drug Regimen')
ceftamin = indexed_results.filter(like='Ceftamin', axis=0)
ceftamin = ceftamin['Tumor Volume (mm3)']
fig1, ax1 = plt.subplots()
ax1.set_title('Ceftamin Outliers')
ax1.set_ylabel('Tumor Volume (mm3)')
ax1.boxplot(ceftamin)
plt.show()
#Determine IQR and calculate quartiles
quartiles = ceftamin.quantile([.25,.5,.75])
lowerq = quartiles[0.25]
upperq = quartiles[0.75]
iqr = upperq-lowerq

print(f"The lower quartile of Tumor Volume is: {round(lowerq,2)}")
print(f"The upper quartile of Tumor Volume is: {round(upperq,2)}")
print(f"The interquartile range of Tumor Volume is: {round(iqr,2)}")
print(f"The the median of Tumor Volume is: {round(quartiles[0.5],2)} ")
lower_bound = lowerq - (1.5*iqr)
upper_bound = upperq + (1.5*iqr)
print(f"Values below {round(lower_bound,2)} are potentially outliers.")
print(f"Values above {round(upper_bound,2)} are potentially outliers.")

# %%
indexed_results = filtered_results.set_index('Drug Regimen')
propriva = indexed_results.filter(like='Propriva', axis=0)
propriva = propriva['Tumor Volume (mm3)']
fig1, ax1 = plt.subplots()
ax1.set_title('Propriva Outliers')
ax1.set_ylabel('Tumor Volume (mm3)')
ax1.boxplot(propriva)
plt.show()
#Determine IQR and calculate quartiles
quartiles = propriva.quantile([.25,.5,.75])
lowerq = quartiles[0.25]
upperq = quartiles[0.75]
iqr = upperq-lowerq

print(f"The lower quartile of Tumor Volume is: {round(lowerq,2)}")
print(f"The upper quartile of Tumor Volume is: {round(upperq,2)}")
print(f"The interquartile range of Tumor Volume is: {round(iqr,2)}")
print(f"The the median of Tumor Volume is: {round(quartiles[0.5],2)} ")
lower_bound = lowerq - (1.5*iqr)
upper_bound = upperq + (1.5*iqr)
print(f"Values below {round(lower_bound,2)} are potentially outliers.")
print(f"Values above {round(upper_bound,2)} are potentially outliers.")

# %%
indexed_results = filtered_results.set_index('Drug Regimen')
capomulin = indexed_results.filter(like='Capomulin', axis=0)
capomulin = capomulin['Tumor Volume (mm3)']
fig1, ax1 = plt.subplots()
ax1.set_title('Capomulin Outliers')
ax1.set_ylabel('Tumor Volume (mm3)')
ax1.boxplot(capomulin)
plt.show()
#Determine IQR and calculate quartiles
quartiles = capomulin.quantile([.25,.5,.75])
lowerq = quartiles[0.25]
upperq = quartiles[0.75]
iqr = upperq-lowerq

print(f"The lower quartile of Tumor Volume is: {round(lowerq,2)}")
print(f"The upper quartile of Tumor Volume is: {round(upperq,2)}")
print(f"The interquartile range of Tumor Volume is: {round(iqr,2)}")
print(f"The the median of Tumor Volume is: {round(quartiles[0.5],2)} ")
lower_bound = lowerq - (1.5*iqr)
upper_bound = upperq + (1.5*iqr)
print(f"Values below {round(lower_bound,2)} are potentially outliers.")
print(f"Values above {round(upper_bound,2)} are potentially outliers.")

# %%
# Generate a scatter plot of mouse weight versus average tumor volume for the Capomulin regimen
capomulin_df = combined_results.set_index('Drug Regimen').loc["Capomulin",:]
grouped_data = capomulin_df.groupby('Mouse ID')

capomulin_scatter = pd.DataFrame(grouped_data.mean())

avg_tumor = capo_scatter.loc[:,'Tumor Volume (mm3)'].to_list()

weight = capo_scatter.loc[:,'Weight (g)'].to_list()

#average_tumor = capomulin_df.groupby('Mouse ID')["Tumor Volume (mm3)"].mean()
plt.scatter(weight, average_tumor, marker='o', facecolors='blue',edgecolors='black', s=weight, alpha=0.75)
